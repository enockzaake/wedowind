# %% [markdown]
# #### EDA + FEATURE ENGINEERING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# Load the CSV file with original target signals
print("Loading csv...")
df = pd.read_csv("../datasets/rotor_icing.csv")

# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%d-%m-%Y')

# Create labels based on the date
df['icing'] = df['timestamp'].apply(lambda x: 1 if x.date() >= pd.to_datetime('2022-12-17').date() else 0)

# Define the target signals
target_signals = ["wind_speed", "power_output", "rotor_speed", "temperature", "rotor_acceleration"]

# Fill missing values with 0
df.fillna(0, inplace=True)

# Plot box plots for each feature to visualize outliers
plt.figure(figsize=(15, 10))
for i, col in enumerate(target_signals, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# Function to remove outliers using IQR
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
        df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
    return df

# Remove outliers
df = remove_outliers(df, target_signals)

# Plot box plots after removing outliers
plt.figure(figsize=(15, 10))
for i, col in enumerate(target_signals, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col} after Removing Outliers')
plt.tight_layout()
plt.show()

# Normalize the target signals
scaler = MinMaxScaler()
df[target_signals] = scaler.fit_transform(df[target_signals])

# Plot the normalized features
plt.figure(figsize=(15, 10))
for i, col in enumerate(target_signals, 1):
    plt.subplot(2, 3, i)
    sns.lineplot(x=df.index, y=df[col])
    plt.title(f'Normalized {col}')
plt.tight_layout()
plt.show()

# Plot the distribution of each feature
plt.figure(figsize=(15, 10))
for i, col in enumerate(target_signals, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df[target_signals].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Save the final processed data to a new CSV file
df.to_csv("../datasets/processed_rotor_icing.csv", index=False)
print("Final processed data saved to datasets/processed_rotor_icing.csv")
# Out:
# Loading csv...
# Final processed data saved to datasets/processed_rotor_icing.csv

# %% [markdown]
# #### TRAINING AND EVALUATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# Load the processed CSV file
print("Loading processed csv...")
df = pd.read_csv("../datasets/processed_rotor_icing.csv")

# Define the target signals
target_signals = ["wind_speed", "power_output", "rotor_speed", "temperature", "rotor_acceleration"]

# Create sequences for LSTM input
def create_sequences(data, labels, window_size):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data[i:i + window_size])
        targets.append(labels[i + window_size])
    return np.array(sequences), np.array(targets)

SEQ_LEN = 20
X_seq, y_seq = create_sequences(df[target_signals].values, df["icing"].values, SEQ_LEN)

# Train/val/test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# Convert to PyTorch tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
X_test_t = torch.tensor(X_test, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.float32)
y_test_t = torch.tensor(y_test, dtype=torch.float32)

# Create datasets
train_dataset = TensorDataset(X_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, y_val_t)
test_dataset = TensorDataset(X_test_t, y_test_t)

# Create data loaders
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Define LSTM Autoencoder
class LSTMAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.encoder = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.decoder = nn.LSTM(hidden_dim, input_dim, batch_first=True)

    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        _, (h, _) = self.encoder(x)  # h: [1, batch, hidden_dim]
        h_repeat = h.repeat(seq_len, 1, 1).permute(1, 0, 2)  # [batch, seq_len, hidden_dim]
        decoded, _ = self.decoder(h_repeat)
        return decoded


# Define CNN+LSTM Model
class CNNLSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=input_dim, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2)
        )
        self.lstm = nn.LSTM(input_size=32, hidden_size=hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # batch, features, seq_len
        x = self.cnn(x)  # batch, channels, seq_len/2
        x = x.permute(0, 2, 1)  # batch, seq_len/2, channels
        _, (h, _) = self.lstm(x)
        return torch.sigmoid(self.fc(h[-1]))

# Initialize models
input_dim = X_train.shape[2]
hidden_dim = 64

autoencoder = LSTMAutoencoder(input_dim=input_dim, hidden_dim=hidden_dim)
model = CNNLSTMClassifier(input_dim=input_dim, hidden_dim=hidden_dim)

# Set loss and optimizer
criterion = nn.MSELoss()
loss_fn = nn.BCELoss()
optimizer_ae = torch.optim.Adam(autoencoder.parameters(), lr=1e-3)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# Training function for Autoencoder
def train_autoencoder(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0

        for xb, _ in train_loader:
            optimizer.zero_grad()
            outputs = model(xb)
            loss = criterion(outputs, xb)  # Use xb as target for autoencoder
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for xb, _ in val_loader:
                outputs = model(xb)
                loss = criterion(outputs, xb)  # Use xb as target for autoencoder
                val_loss += loss.item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    return train_losses, val_losses

# Training function for CNN+LSTM
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0

        for xb, yb in train_loader:
            optimizer.zero_grad()
            outputs = model(xb).squeeze()
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for xb, yb in val_loader:
                outputs = model(xb).squeeze()
                loss = criterion(outputs, yb)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    return train_losses, val_losses

# Train LSTM Autoencoder
print("Training LSTM Autoencoder...")
train_losses_ae, val_losses_ae = train_autoencoder(autoencoder, train_loader, val_loader, criterion, optimizer_ae, num_epochs=10)

# Train CNN+LSTM Model
print("Training CNN+LSTM Model...")
train_losses, val_losses = train_model(model, train_loader, val_loader, loss_fn, optimizer, num_epochs=10)

# Plot training and validation loss
plt.figure(figsize=(12, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Loading processed csv...
# Training LSTM Autoencoder...
# Epoch 1/10, Train Loss: 0.0141, Val Loss: 0.0121
# Epoch 2/10, Train Loss: 0.0111, Val Loss: 0.0106
# Epoch 3/10, Train Loss: 0.0105, Val Loss: 0.0102
# Epoch 4/10, Train Loss: 0.0095, Val Loss: 0.0090
# Epoch 5/10, Train Loss: 0.0084, Val Loss: 0.0079
# Epoch 6/10, Train Loss: 0.0077, Val Loss: 0.0075
# Epoch 7/10, Train Loss: 0.0073, Val Loss: 0.0072
# Epoch 8/10, Train Loss: 0.0071, Val Loss: 0.0069
# Epoch 9/10, Train Loss: 0.0069, Val Loss: 0.0068
# Epoch 10/10, Train Loss: 0.0067, Val Loss: 0.0066
# Training CNN+LSTM Model...
# Epoch 1/10, Train Loss: 0.0105, Val Loss: 0.0008
# Epoch 2/10, Train Loss: 0.0007, Val Loss: 0.0004
# Epoch 3/10, Train Loss: 0.0011, Val Loss: 0.0003
# Epoch 4/10, Train Loss: 0.0005, Val Loss: 0.0002
# Epoch 5/10, Train Loss: 0.0004, Val Loss: 0.0001
# Epoch 6/10, Train Loss: 0.0003, Val Loss: 0.0001
# Epoch 7/10, Train Loss: 0.0002, Val Loss: 0.0003
# Epoch 8/10, Train Loss: 0.0002, Val Loss: 0.0001
# Epoch 9/10, Train Loss: 0.0001, Val Loss: 0.0000
# Epoch 10/10, Train Loss: 0.0002, Val Loss: 0.0001
# Evaluating LSTM Autoencoder...
# c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 20, 5])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 215
#     213 # Evaluate LSTM Autoencoder
#     214 print("Evaluating LSTM Autoencoder...")
# --> 215 evaluate_model(autoencoder, test_loader, criterion)
#     217 # Evaluate CNN+LSTM Model
#     218 print("Evaluating CNN+LSTM Model...")
#
# Cell In[8], line 207, in evaluate_model(model, test_loader, criterion)
#     205     for xb, yb in test_loader:
#     206         outputs = model(xb).squeeze()
# --> 207         loss = criterion(outputs, yb)
#     208         test_loss += loss.item()
#     210 test_loss /= len(test_loader)
#
# File c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\nn\modules\loss.py:610, in MSELoss.forward(self, input, target)
#     609 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 610     return F.mse_loss(input, target, reduction=self.reduction)
#
# File c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\nn\functional.py:3884, in mse_loss(input, target, size_average, reduce, reduction, weight)
#    3881 if size_average is not None or reduce is not None:
#    3882     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3884 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3886 if weight is not None:
#    3887     if weight.size() != input.size():
#
# File c:\Users\KIIT\Desktop\ML & DL\project\.venv\Lib\site-packages\torch\functional.py:76, in broadcast_tensors(*tensors)
#      74 if has_torch_function(tensors):
#      75     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 76 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (5) must match the size of tensor b (64) at non-singleton dimension 2

# %%
def evaluate_autoencoder(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0

    with torch.no_grad():
        for xb, _ in test_loader:
            outputs = model(xb)
            loss = criterion(outputs, xb)  # compare with input
            test_loss += loss.item()

    test_loss /= len(test_loader)
    print(f'[Autoencoder] Test Loss: {test_loss:.4f}')

def evaluate_classifier(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0

    all_preds = []
    all_targets = []

    with torch.no_grad():
        for xb, yb in test_loader:
            outputs = model(xb).squeeze()
            loss = criterion(outputs, yb)
            test_loss += loss.item()

            all_preds.extend(outputs.round().cpu().numpy())
            all_targets.extend(yb.cpu().numpy())

    test_loss /= len(test_loader)
    print(f'[Classifier] Test Loss: {test_loss:.4f}')
    print(classification_report(all_targets, all_preds))


# Evaluate LSTM Autoencoder
print("Evaluating LSTM Autoencoder...")
evaluate_autoencoder(autoencoder, test_loader, criterion)

# Evaluate CNN+LSTM Model
print("\nEvaluating CNN+LSTM Model...")
evaluate_classifier(model, test_loader, loss_fn)
# Out:
# Evaluating LSTM Autoencoder...
# [Autoencoder] Test Loss: 0.0066
#
# Evaluating CNN+LSTM Model...
# [Classifier] Test Loss: 0.0000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     16848
#          1.0       1.00      1.00      1.00     49643
#
#     accuracy                           1.00     66491
#    macro avg       1.00      1.00      1.00     66491
# weighted avg       1.00      1.00      1.00     66491

# %%
# Save models
torch.save(autoencoder.state_dict(), 'lstm_autoencoder.pth')
torch.save(model.state_dict(), 'cnn_lstm_model.pth')
print("Models saved to lstm_autoencoder.pth and cnn_lstm_model.pth")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Save models
# ----> 2 torch.save(autoencoder.state_dict(), 'lstm_autoencoder.pth')
#       3 torch.save(model.state_dict(), 'cnn_lstm_model.pth')
#       4 print("Models saved to lstm_autoencoder.pth and cnn_lstm_model.pth")
#
# NameError: name 'torch' is not defined
